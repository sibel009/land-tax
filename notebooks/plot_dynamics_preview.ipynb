# %%
import numpy as np 
import matplotlib.pyplot as plt
import json
import matplotlib.ticker as mtick

# %%
# import parameters
with open('ParamEndog_uncons_calib.json') as js:
    params = json.load(js)

# %%
def plot_dynamics(ax, exprmt, init_ss, tax_rate_id, lab, ls):
    
    ax[0,0].set_title(r'$K$')
    ax[0,0].plot((exprmt[:,0] - init_ss['K'])/np.abs(init_ss['K']), ls=ls)
    ax[0,0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[0,1].set_title(r'$S$')
    ax[0,1].plot((exprmt[:,1] - init_ss['S'])/np.abs(init_ss['S']), ls=ls)
    ax[0,1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[0,2].set_title(r'$s$')
    ax[0,2].plot((exprmt[:,2] - init_ss['s'])/np.abs(init_ss['s']), ls=ls)
    ax[0,2].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[0,3].set_title(r'$Y$')
    ax[0,3].plot((exprmt[:,20] - init_ss['Y'])/init_ss['Y'], ls=ls)
    ax[0,3].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    ax[0,4].set_title(r'$K_{inv}/K^{*}_{init}$')
    ax[0,4].plot((exprmt[:,9] - exprmt[:,0])/init_ss['K'], ls=ls)
    ax[0,4].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[1,0].set_title(r'$\mathcal{L}$')
    ax[1,0].plot((exprmt[:,3] - init_ss['L'])/init_ss['L'], ls=ls)
    ax[1,0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[1,1].set_title(r'$\mathcal{l}$')
    ax[1,1].plot((exprmt[:,4] - init_ss['l'])/init_ss['l'], ls=ls)
    ax[1,1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[1,2].set_title(r'$\mathcal{L}_{R}$')
    ax[1,2].plot((exprmt[:,17] - init_ss['LR'])/init_ss['LR'], ls=ls)
    ax[1,2].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[1,3].set_title(r'$p^{\mathcal{L}_{R}}$')
    ax[1,3].plot((exprmt[:,8] - init_ss['p_LR'])/init_ss['p_LR'], ls=ls)
    ax[1,3].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    ax[1,4].set_title(r'$S_{inv}/S^{*}_{init}$')
    ax[1,4].plot((exprmt[:,10] - exprmt[:,1])/init_ss['S'], ls=ls)
    ax[1,4].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[2,0].set_title(r'$H$')
    ax[2,0].plot((exprmt[:,19] - init_ss['H'])/init_ss['H'], ls=ls)
    ax[2,0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[2,1].set_title(r'$h$')
    ax[2,1].plot((exprmt[:,18] - init_ss['h'])/init_ss['h'], ls=ls)
    ax[2,1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[2,2].set_title(r'$R^{H}_{gross}$')
    ax[2,2].plot((exprmt[:,23] - init_ss['R_H_gross'])/init_ss['R_H_gross'], ls=ls)
    ax[2,2].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[2,3].set_title(r'$R^{K}_{gross}$')
    ax[2,3].plot((exprmt[:,22] - init_ss['R_K_gross'])/init_ss['R_K_gross'], ls=ls)
    ax[2,3].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    ax[2,4].set_title(r'$s_{inv}/s^{*}_{init}$')
    ax[2,4].plot((exprmt[:,11] - exprmt[:,2])/init_ss['s'], ls=ls)
    ax[2,4].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[3,0].set_title(r'$C$')
    ax[3,0].plot((exprmt[:,6] - init_ss['C'])/init_ss['C'], ls=ls)
    ax[3,0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[3,1].set_title(r'$c$')
    ax[3,1].plot((exprmt[:,5] - init_ss['c'])/init_ss['c'], ls=ls)
    ax[3,1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[3,2].set_title(r'$C_R$')
    ax[3,2].plot((exprmt[:,7] - init_ss['C_R'])/init_ss['C_R'], ls=ls)
    ax[3,2].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[3,3].set_title('Wage')
    ax[3,3].plot((exprmt[:,24] - init_ss['wage'])/init_ss['wage'], ls=ls)
    ax[3,3].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    # new
    ax[3,4].set_title(r'$(LDV_{t+1}-LDV_{t})/(LDV^{*}_{init})$')
    ax[3,4].plot((exprmt[:,14] - exprmt[:,16])/init_ss['LDV'], ls=ls)
    ax[3,4].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    ax[4,0].set_title('GDP')
    ax[4,0].plot((exprmt[:,29] - init_ss['GDP'])/init_ss['GDP'], ls=ls)
    ax[4,0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[4,1].set_title('Tax rate')
    ax[4,1].plot(exprmt[:,tax_rate_id], ls=ls)

    transfer2GDP = exprmt[:,30]/init_ss['GDP']
    ax[4,2].set_title('Transfer/GDP')
    ax[4,2].plot(transfer2GDP, ls=ls)
    ax[4,2].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    ax[4,3].set_title('Welfare')
    ax[4,3].plot((exprmt[:,28] - init_ss['welfare'])/np.abs(init_ss['welfare']), ls=ls, label=lab)
    ax[4,3].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
    
    ax[4,4].set_title('Marginal land development cost')
    ax[4,4].plot(exprmt[:,31], ls=ls)

    ax[5,0].set_title('Total land development cost')
    ax[5,0].plot(exprmt[:,32], ls=ls)
    
    # new
    # ax[4,4].set_title(r'$\frac{R^{R}\mathcal{L}^{R}}{Y + R^{R}\mathcal{L}^{R}}$')
    # ax[4,4].plot((params['R_R']*exprmt[:,17])/(exprmt[:,20] + params['R_R']*exprmt[:,17]), ls=ls)
    # ax[4,4].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))

    

    for i in range(1,5):
        # ax[i,i].set_xlim([-10,500])
        ax[4,i].set_xlabel(r'$t$')
        
    ax[5,0].set_xlabel(r'$t$')

# %%
# Experiment 1
exprmt1 = np.loadtxt(open("dynamics/exprmt1_PF.csv", "rb"), delimiter=",")

with open('dynamics/exprmt1_terminal.json') as file:
    init_ss_exprmt1 = json.load(file)       # terminal is the steady state capital stock (init is the shocked K)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt1, init_ss_exprmt1, 31, None, '-')
for i in range(1, 5):
    fig.delaxes(ax[5, i])

fig.suptitle('A 20% negative shock to the capital stock')
plt.tight_layout()
plt.show()

# %%
# Experiment 2
exprmt2_PF = np.loadtxt(open("dynamics/exprmt2_PF.csv", "rb"), delimiter=",")
exprmt2_MIT = np.loadtxt(open("dynamics/exprmt2_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt2_init.json') as file:
    init_ss_exprmt2 = json.load(file)
    
fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)


plot_dynamics(ax, exprmt2_PF, init_ss_exprmt2, 34, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt2_MIT, init_ss_exprmt2, 34, 'As a surprise', '--')
    
fig.delaxes(ax[-1,-1])
fig.suptitle(r'A permanent increase in capital tax to 2% at $t=100$')

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 3
exprmt3_PF = np.loadtxt(open("dynamics/exprmt3_PF.csv", "rb"), delimiter=",")
exprmt3_MIT = np.loadtxt(open("dynamics/exprmt3_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt3_init.json') as file:
    init_ss_exprmt3 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt3_PF, init_ss_exprmt3, 35, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt3_MIT, init_ss_exprmt3, 35, 'As a surprise', '--')

fig.delaxes(ax[-1,-1])
fig.suptitle(r'A permanent increase in uniform tax on land surface to 2% at $t=100$')

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 4
exprmt4_PF = np.loadtxt(open("dynamics/exprmt4_PF.csv", "rb"), delimiter=",")
exprmt4_MIT = np.loadtxt(open("dynamics/exprmt4_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt4_init.json') as file:
    init_ss_exprmt4 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt4_PF, init_ss_exprmt4, 35, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt4_MIT, init_ss_exprmt4, 35, 'As a surprise', '--')
    
fig.suptitle(r'Geometric increase in uniform tax on land surface to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 16
#      13 fig.suptitle(r'Geometric increase in uniform tax on land surface to 2% from $t=100$')
#      14 fig.delaxes(ax[-1,-1])
# ---> 16 plt.tight_layout()
#      18 ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
#      19 plt.show()
#
# File ~/miniforge3/envs/my-env/lib/python3.10/site-packages/matplotlib/pyplot.py:2349, in tight_layout(pad, h_pad, w_pad, rect)
#    2347 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2348 def tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None):
# -> 2349     return gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File ~/miniforge3/envs/my-env/lib/python3.10/site-packages/matplotlib/figure.py:3509, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3507 previous_engine = self.get_layout_engine()
# ...

# %%
# Experiment 5
exprmt5_PF = np.loadtxt(open("dynamics/exprmt5_PF.csv", "rb"), delimiter=",")
exprmt5_MIT = np.loadtxt(open("dynamics/exprmt5_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt5_init.json') as file:
    init_ss_exprmt5 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt5_PF, init_ss_exprmt5, 35, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt5_MIT, init_ss_exprmt5, 35, 'As a surprise', '--')
    
fig.suptitle(r'Linear increase in uniform tax on land surface to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 6
exprmt6_PF = np.loadtxt(open("dynamics/exprmt6_PF.csv", "rb"), delimiter=",")
exprmt6_MIT = np.loadtxt(open("dynamics/exprmt6_MIT.csv", "rb"), delimiter=",")


with open('dynamics/exprmt6_init.json') as file:
    init_ss_exprmt6 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt6_PF, init_ss_exprmt6, 35, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt6_MIT, init_ss_exprmt6, 35, 'As a surprise', '--')

fig.suptitle(r'Smoothed linear increase in uniform tax on land surface to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 7
exprmt7_PF = np.loadtxt(open("dynamics/exprmt7_PF.csv", "rb"), delimiter=",")
exprmt7_MIT = np.loadtxt(open("dynamics/exprmt7_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt7_init.json') as file:
    init_ss_exprmt7 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt7_PF, init_ss_exprmt7, 38, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt7_MIT, init_ss_exprmt7, 38, 'As a surprise', '--')

    
fig.suptitle(r'A permanent increase in uniform-rate tax on land value to 2% at $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 8
exprmt8_PF = np.loadtxt(open("dynamics/exprmt8_PF.csv", "rb"), delimiter=",")
exprmt8_MIT = np.loadtxt(open("dynamics/exprmt8_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt8_init.json') as file:
    init_ss_exprmt8 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt8_PF, init_ss_exprmt8, 38, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt8_MIT, init_ss_exprmt8, 38, 'As a surprise', '--')
    
fig.suptitle(r'Geometric increase in uniform-rate tax on land value to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 9
exprmt9_PF = np.loadtxt(open("dynamics/exprmt9_PF.csv", "rb"), delimiter=",")
exprmt9_MIT = np.loadtxt(open("dynamics/exprmt9_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt9_init.json') as file:
    init_ss_exprmt9 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt9_PF, init_ss_exprmt9, 38, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt9_MIT, init_ss_exprmt9, 38, 'As a surprise', '--')
    
fig.suptitle(r'Linear increase in uniform-rate tax on land value to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 10
exprmt10_PF = np.loadtxt(open("dynamics/exprmt10_PF.csv", "rb"), delimiter=",")
exprmt10_MIT = np.loadtxt(open("dynamics/exprmt10_MIT.csv", "rb"), delimiter=",")


with open('dynamics/exprmt10_init.json') as file:
    init_ss_exprmt10 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt10_PF, init_ss_exprmt10, 38, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt10_MIT, init_ss_exprmt10, 38, 'As a surprise', '--')

fig.suptitle(r'Smoothed linear increase in uniform-rate tax on land value to 2% from $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 11
exprmt11_PF = np.loadtxt(open("dynamics/exprmt11_PF.csv", "rb"), delimiter=",")
exprmt11_MIT = np.loadtxt(open("dynamics/exprmt11_MIT.csv", "rb"), delimiter=",")


with open('dynamics/exprmt11_init.json') as file:
    init_ss_exprmt11 = json.load(file)

fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)

plot_dynamics(ax, exprmt11_PF, init_ss_exprmt11, 41, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt11_MIT, init_ss_exprmt11, 41, 'As a surprise', '--')

fig.suptitle(r'A permanent increase in tax on land purchase to 2% at $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()

# %%
# Experiment 12
exprmt12_PF = np.loadtxt(open("dynamics/exprmt12_PF.csv", "rb"), delimiter=",")
exprmt12_MIT = np.loadtxt(open("dynamics/exprmt12_MIT.csv", "rb"), delimiter=",")

with open('dynamics/exprmt12_init.json') as file:
    init_ss_exprmt12 = json.load(file)
    
fig, ax = plt.subplots(6, 5, figsize=[15, 9], dpi=200, sharex=True)


plot_dynamics(ax, exprmt12_PF, init_ss_exprmt12, 34, r'Pre-announced at $t=0$', '-')
plot_dynamics(ax, exprmt12_MIT, init_ss_exprmt12, 34, 'As a surprise', '--')
    
fig.suptitle(r'A transient (one-period) increase in capital tax to 2% at $t=100$')
fig.delaxes(ax[-1,-1])

plt.tight_layout()

ax[4,3].legend(bbox_to_anchor=(0, -0.4), ncol=2)
plt.show()
